# %%
from google.colab import files
files.upload()  #this will prompt you to upload the kaggle.json
# Out:
#      <input type="file" id="files-aca10897-69e7-43fd-9eb1-599c1b3b8dc6" name="files[]" multiple disabled />
#      <output id="result-aca10897-69e7-43fd-9eb1-599c1b3b8dc6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-9b47f366bfa7> in <module>()
#       1 from google.colab import files
# ----> 2 files.upload()  #this will prompt you to upload the kaggle.json
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
# ...
